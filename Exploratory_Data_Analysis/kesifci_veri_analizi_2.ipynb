# %%
import pandas as pd
import numpy as np
import seaborn as sns


fmri = sns.load_dataset("fmri")
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.shape
# Out:
# (1064, 5)

# %%
df.dtypes
# Out:
# subject       object
# timepoint      int64
# event         object
# region        object
# signal       float64
# dtype: object

# %%
df["timepoint"].describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df["signal"].describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
sns.jointplot(x="timepoint",y="signal",data=df,kind="reg")

# %%
df.groupby("timepoint")["signal"].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal")["timepoint"].count()
# Out:
# signal
# -0.255486    1
# -0.238474    1
# -0.224351    1
# -0.181241    1
# -0.178510    1
# -0.176453    1
# -0.169312    1
# -0.160821    1
# -0.159772    1
# -0.157834    1
# -0.155546    1
# -0.154564    1
# -0.152929    1
# -0.152652    1
# -0.150709    1
# -0.150693    1
# -0.149785    1
# -0.149299    1
# -0.146048    1
# -0.143302    1
# -0.138152    1
# -0.136592    1
# -0.136059    1
# -0.134828    1
# -0.134795    1
# -0.133647    1
# -0.133171    1
# -0.133041    1
# -0.132768    1
# -0.132442    1
#             ..
#  0.260057    1
#  0.261283    1
#  0.262771    1
#  0.263207    1
#  0.270956    1
#  0.282222    1
#  0.287294    1
#  0.291884    1
#  0.294639    1
#  0.296960    1
#  0.298009    1
#  0.307250    1
#  0.312811    1
#  0.315860    1
#  0.319009    1
#  0.321335    1
#  0.324265    1
#  0.337143    1
#  0.340480    1
#  0.345918    1
#  0.346775    1
#  0.381495    1
#  0.390466    1
#  0.405840    1
#  0.410661    1
#  0.455575    1
#  0.460896    1
# ...

# %%
df.groupby("timepoint")["signal"].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# ...

# %%
#koyu mavi çizgi ortalamalara karşılık geliyor.
#koyu mavi çizginin etrafındaki gölgeler standart sapmaları gösteriyor.(Güven aralıkları)
sns.lineplot(x="timepoint",y="signal",data=df)

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event",data=df)

# %%
sns.lineplot(x="timepoint",y="signal",
             hue="event",style="event",
             markers=True,dashes=False,data=df)

# %%
sns.lineplot(x="timepoint",y="signal",hue="region",style="event",data=df)

# %% [markdown]
# Zaman Serisi Grafikleri

# %%
# !pip install pandas-datareader

# %%
import pandas as pd
from pandas_datareader import data
import pandas_datareader as dr
apple = dr.get_data_yahoo('AAPl', start='2015-01-01', end='2018-12-30')
df=apple.copy()
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2015-01-02  111.440002  107.349998  111.389999  109.330002  53204600.0
# 2015-01-05  108.650002  105.410004  108.290001  106.250000  64285500.0
# 2015-01-06  107.430000  104.629997  106.540001  106.260002  65797100.0
# 2015-01-07  108.199997  106.699997  107.199997  107.750000  40105900.0
# 2015-01-08  112.150002  108.699997  109.230003  111.889999  59364500.0
#
#              Adj Close
# Date
# 2015-01-02  101.138702
# 2015-01-05   98.289474
# 2015-01-06   98.298729
# 2015-01-07   99.677094
# 2015-01-08  103.506897

# %%
df.shape
# Out:
# (1005, 6)

# %%
df.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn

# %%
kapanis = df["Close"]
kapanis.head()
# Out:
# Date
# 2015-01-02    109.330002
# 2015-01-05    106.250000
# 2015-01-06    106.260002
# 2015-01-07    107.750000
# 2015-01-08    111.889999
# Name: Close, dtype: float64

# %%
df.shape
# Out:
# (1005, 6)

# %%
kapanis.plot()

# %%
kapanis.index = pd.DatetimeIndex(kapanis.index)

# %%
kapanis.plot()

# %%
# %config InlineBackend.figure_format = "retina"
import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize':(18,9.)})
sns.set_style("whitegrid")

# %%
kapanis.plot(style="-")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-957516c6babf> in <module>
# ----> 1 kapanis.plot(style="-")
#
# NameError: name 'kapanis' is not defined

# %%
#Hareketli ortalama:Borsa jargonunda hisse senetleri fiyatlarının 3,5,7 günlük durumunun ne olduğunu
#ifade eden bir ortalama türüdür.Hisse senetlerinin kendi değerlerinin üstüne konur.Buda
#hisse senedinin değerlerinin trendinin eğilimini ortaya çıkarır.
#Örneğin 5 günlük hareketli ortalama 7 günlükten daha büyükse bu durumda hisse senedinin değerinin
#son zamanlarda artış trendinde olduğu anlamına gelir.

# %%
yedi = kapanis.rolling(window = 7).mean()
on = kapanis.rolling(window = 10).mean()
yirmi = kapanis.rolling(window = 20).mean()
otuz = kapanis.rolling(window = 30).mean()

# %%
yedi.head()
# Out:
# Date
# 2015-01-02   NaN
# 2015-01-05   NaN
# 2015-01-06   NaN
# 2015-01-07   NaN
# 2015-01-08   NaN
# Name: Close, dtype: float64

# %%
yedi.head(10)
# Out:
# Date
# 2015-01-02           NaN
# 2015-01-05           NaN
# 2015-01-06           NaN
# 2015-01-07           NaN
# 2015-01-08           NaN
# 2015-01-09           NaN
# 2015-01-12    108.962858
# 2015-01-13    109.090001
# 2015-01-14    109.597144
# 2015-01-15    109.677144
# Name: Close, dtype: float64

# %%
yedi.head(15)
# Out:
# Date
# 2015-01-02           NaN
# 2015-01-05           NaN
# 2015-01-06           NaN
# 2015-01-07           NaN
# 2015-01-08           NaN
# 2015-01-09           NaN
# 2015-01-12    108.962858
# 2015-01-13    109.090001
# 2015-01-14    109.597144
# 2015-01-15    109.677144
# 2015-01-16    109.425715
# 2015-01-20    108.972858
# 2015-01-21    108.621429
# 2015-01-22    109.071430
# 2015-01-23    109.465716
# Name: Close, dtype: float64

# %%
kapanis.plot(style="-");
yedi.plot(style="--")
on.plot(style="-.")
yirmi.plot(style=":")
otuz.plot()
plt.legend(["input","yedi","on","yirmi","otuz"],loc="upper left");
plt.xlim("2017","2018")
# Out:
# (736330.0, 736695.0)
